# %% [markdown]
# # Settings
# ### Import modules

# %%
import os
import librosa, librosa.display
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np

# %% [markdown]
# ### Initialize & Checking Folders (Path)

# %%
# Audio Data (Source)
audio_list_path = './audio_list'
audio_list = os.listdir(audio_list_path)
print(f"Audio_list : {audio_list}")

# Results 
result_path = './result'
result = os.listdir(result_path)
print(f"Result : {result}")
# Out:
# Audio_list : ['oasis.wav', 'oasis_karaoke.wav', 'only_drum.wav']
# Result : []

# %% [markdown]
# ## Defining three methods
# ### 1. Extract only percussive sound(drum) from audio samples

# %%
# showing audio samples
audio_list = os.listdir(audio_list_path)
print(f"Let's extract percussive sound from {audio_list}")
# Out:
# Let's extract percussive sound from ['oasis.wav', 'oasis_karaoke.wav', 'only_drum.wav']

# %%
# audio_data --> percussive_data 
def percussive_audio_data(audio_file, save_file):
    # loading .wav file 
    y, sr = librosa.load(audio_file)
    
    # harmonic percussive source seperation
    harmonic, percussive = librosa.decompose.hpss(librosa.stft(y))
    # saving only percussive source
    y = librosa.istft(percussive)
    y = ((y-min(y))/(max(y)-min(y)))*1.4-0.7
    
    # showing the waveform of the percussive source only
    plt.figure()
    librosa.display.waveshow(y, alpha=0.5)
    plt.xlabel("Time (s)")
    plt.ylabel("Aplitude")
    plt.title(f"{save_file}")
    
    # saving new file (only percussive sound)
    sf.write(save_file + '.wav', y, sr)
    print(f"'{save_file}'.wav extracted from '{audio_file}'", end="\n\n")

# %%
percussive_list = list()
# extracting only percussive sound from .wav file 
for audio in audio_list:
    # setting audio_path in a result directory
    audio_path = os.path.join(result_path, audio[:-4])
    percussive_list.append(audio[:-4] + '_p.wav')
    
    # Generating audio directory in a result directory
    try:
        os.makedirs(audio_path)
        print(f"{audio_path} folder created.")
    except:
        print("You already have folders")
    
    if audio.find('wav') != -1:
        # Setting source path & save path 
        audio_file = audio_list_path + '/' + audio
        percussive_file = audio_path + '/' + audio[:-4] + '_p'
        percussive_audio_data(audio_file, percussive_file)     

print("##################################################################")
print(f"Extracted complete {percussive_list}")
# Out:
# ./result\oasis folder created.
# './result\oasis/oasis_p'.wav extracted from './audio_list/oasis.wav'
#
# ./result\oasis_karaoke folder created.
# './result\oasis_karaoke/oasis_karaoke_p'.wav extracted from './audio_list/oasis_karaoke.wav'
#
# ./result\only_drum folder created.
# './result\only_drum/only_drum_p'.wav extracted from './audio_list/only_drum.wav'
#
# ##################################################################
# Extracted complete ['oasis_p.wav', 'oasis_karaoke_p.wav', 'only_drum_p.wav']

# %% [markdown]
# ### 2. Trim percussive sound one by one

# %%
# checking percussive_list
audio_list = os.listdir(audio_list_path)
print("Let's split percussive sound by using Onset Detection.")
print(percussive_list)
# Out:
# Let's split percussive sound by using Onset Detection.
# ['oasis_p.wav', 'oasis_karaoke_p.wav', 'only_drum_p.wav']

# %%
# percussive_data --> trim_data 
def trim_percussive_data(percussive_file, save_file, path):
    # loading .wav file 
    y, sr = librosa.load(percussive_file)
    # setting prefix and suffix (To make a sample with a fixed size)
    append_front = np.array([0 for _ in range(92)])
    append_back = np.array([0 for _ in range(900)])
    
    # onset detection
    onset_time = librosa.onset.onset_detect(y=y, sr=sr, units='time')
    f = open(path + "/onset_time.txt", 'w')
    print(f"{len(onset_time)} event(s) has been detected.")
    
    # Trim, using Onset Detection Time
    # plt.figure(figsize=[20,55])
    for i in range(len(onset_time)):
        ny = y[int(sr*(onset_time[i]-0.03)):int(sr*(onset_time[i]+0.11))]
        ny = np.concatenate((append_front, ny, append_back), axis=0)
        
        # showing the waveform of each sounds
        # plt.subplot(58,1,i+1)
        # plt.plot(ny)
        # plt.ylim(-0.7,0.7)
        
        # saving files (trimmed samples)
        trim_file = save_file + '_' + str(i + 1)
        sf.write(trim_file + '.wav', ny, sr)
        f.write(str(onset_time[i]) +'\n')
        print(f"{onset_time[i]} \t(sec): '{trim_file}' created.") 
    
    f.close()
    print(f"All files are {len(ny)/sr} sec long.\n\n")

# %%
trim_path_list = list()

for percussive_name in percussive_list:
    print(f"Start Trim '{percussive_name}'")
    # setting percussive_path & trim_path in a result directory
    percussive_path = result_path + '/' + percussive_name[:-6]
    trim_path = percussive_path + '/trim'
    trim_path_list.append(trim_path)
    
    # Generating trim directory in a result/audio directory
    try:
        os.makedirs(trim_path)
        print(f"{trim_path} folder created.")
    except:
        print("You already have folders")
        
    if percussive_name.find('wav') != -1:
        # Setting source path & save path 
        percussive_file = percussive_path + '/' + percussive_name
        trim_file = trim_path + '/' + percussive_name[:-4]
        trim_percussive_data(percussive_file, trim_file, percussive_path)
# Out:
# Start Trim 'oasis_p.wav'
# ./result/oasis/trim folder created.
# 54 event(s) has been detected.
# 0.06965986394557823 	(sec): './result/oasis/trim/oasis_p_1' created.
# 0.16253968253968254 	(sec): './result/oasis/trim/oasis_p_2' created.
# 0.2089795918367347 	(sec): './result/oasis/trim/oasis_p_3' created.
# 0.4179591836734694 	(sec): './result/oasis/trim/oasis_p_4' created.
# 0.5108390022675737 	(sec): './result/oasis/trim/oasis_p_5' created.
# 0.7198185941043084 	(sec): './result/oasis/trim/oasis_p_6' created.
# 0.8591383219954648 	(sec): './result/oasis/trim/oasis_p_7' created.
# 1.207437641723356 	(sec): './result/oasis/trim/oasis_p_8' created.
# 1.3931972789115645 	(sec): './result/oasis/trim/oasis_p_9' created.
# 1.555736961451247 	(sec): './result/oasis/trim/oasis_p_10' created.
# 1.7647165532879818 	(sec): './result/oasis/trim/oasis_p_11' created.
# 1.9272562358276644 	(sec): './result/oasis/trim/oasis_p_12' created.
# 2.066575963718821 	(sec): './result/oasis/trim/oasis_p_13' created.
# 2.2523356009070294 	(sec): './result/oasis/trim/oasis_p_14' created.
# 2.5309750566893423 	(sec): './result/oasis/trim/oasis_p_15' created.
# 2.7631746031746034 	(sec): './result/oasis/trim/oasis_p_16' created.
# 2.948934240362812 	(sec): './result/oasis/trim/oasis_p_17' created.
# 3.111473922902494 	(sec): './result/oasis/trim/oasis_p_18' created.
# 3.297233560090703 	(sec): './result/oasis/trim/oasis_p_19' created.
# 3.436553287981859 	(sec): './result/oasis/trim/oasis_p_20' created.
# 3.6687528344671203 	(sec): './result/oasis/trim/oasis_p_21' created.
# 3.9706122448979593 	(sec): './result/oasis/trim/oasis_p_22' created.
# 4.156371882086168 	(sec): './result/oasis/trim/oasis_p_23' created.
# 4.31891156462585 	(sec): './result/oasis/trim/oasis_p_24' created.
# 4.504671201814059 	(sec): './result/oasis/trim/oasis_p_25' created.
# 4.6439909297052155 	(sec): './result/oasis/trim/oasis_p_26' created.
# 4.85297052154195 	(sec): './result/oasis/trim/oasis_p_27' created.
# 5.015510204081632 	(sec): './result/oasis/trim/oasis_p_28' created.
# 5.363809523809524 	(sec): './result/oasis/trim/oasis_p_29' created.
# 5.456689342403628 	(sec): './result/oasis/trim/oasis_p_30' created.
# 5.526349206349207 	(sec): './result/oasis/trim/oasis_p_31' created.
# 5.688888888888889 	(sec): './result/oasis/trim/oasis_p_32' created.
# 5.851428571428571 	(sec): './result/oasis/trim/oasis_p_33' created.
# 5.897868480725624 	(sec): './result/oasis/trim/oasis_p_34' created.
# 6.03718820861678 	(sec): './result/oasis/trim/oasis_p_35' created.
# 6.199727891156463 	(sec): './result/oasis/trim/oasis_p_36' created.
# 6.3854875283446715 	(sec): './result/oasis/trim/oasis_p_37' created.
# 6.733786848072563 	(sec): './result/oasis/trim/oasis_p_38' created.
# 6.896326530612245 	(sec): './result/oasis/trim/oasis_p_39' created.
# 7.082086167800454 	(sec): './result/oasis/trim/oasis_p_40' created.
# 7.267845804988662 	(sec): './result/oasis/trim/oasis_p_41' created.
# 7.4071655328798185 	(sec): './result/oasis/trim/oasis_p_42' created.
# 7.546485260770975 	(sec): './result/oasis/trim/oasis_p_43' created.
# 7.732244897959184 	(sec): './result/oasis/trim/oasis_p_44' created.
# 7.778684807256236 	(sec): './result/oasis/trim/oasis_p_45' created.
# 8.034104308390022 	(sec): './result/oasis/trim/oasis_p_46' created.
# 8.243083900226758 	(sec): './result/oasis/trim/oasis_p_47' created.
# 8.289523809523809 	(sec): './result/oasis/trim/oasis_p_48' created.
# 8.475283446712018 	(sec): './result/oasis/trim/oasis_p_49' created.
# 8.614603174603175 	(sec): './result/oasis/trim/oasis_p_50' created.
# 8.800362811791382 	(sec): './result/oasis/trim/oasis_p_51' created.
# 8.962902494331066 	(sec): './result/oasis/trim/oasis_p_52' created.
# 9.148662131519274 	(sec): './result/oasis/trim/oasis_p_53' created.
# 9.47374149659864 	(sec): './result/oasis/trim/oasis_p_54' created.
# All files are 0.07501133786848073 sec long.
#
#
# Start Trim 'oasis_karaoke_p.wav'
# ./result/oasis_karaoke/trim folder created.
# 51 event(s) has been detected.
# 0.06965986394557823 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_1' created.
# 0.25541950113378686 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_2' created.
# 0.44117913832199546 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_3' created.
# 0.626938775510204 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_4' created.
# 0.7894784580498866 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_5' created.
# 0.9752380952380952 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_6' created.
# 1.1377777777777778 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_7' created.
# 1.3003174603174603 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_8' created.
# 1.486077097505669 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_9' created.
# 1.6486167800453515 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_10' created.
# 1.811156462585034 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_11' created.
# 2.020136054421769 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_12' created.
# 2.159455782312925 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_13' created.
# 2.345215419501134 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_14' created.
# 2.5309750566893423 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_15' created.
# 2.670294784580499 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_16' created.
# 3.0418140589569163 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_17' created.
# 3.2043537414965986 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_18' created.
# 3.3901133786848074 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_19' created.
# 3.5526530612244898 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_20' created.
# 3.7151927437641725 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_21' created.
# 3.900952380952381 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_22' created.
# 4.063492063492063 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_23' created.
# 4.4117913832199545 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_24' created.
# 4.574331065759637 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_25' created.
# 4.73687074829932 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_26' created.
# 4.922630385487528 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_27' created.
# 5.085170068027211 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_28' created.
# 5.270929705215419 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_29' created.
# 5.433469387755102 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_30' created.
# 5.7817687074829935 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_31' created.
# 5.944308390022676 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_32' created.
# 6.130068027210885 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_33' created.
# 6.292607709750567 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_34' created.
# 6.478367346938776 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_35' created.
# 6.640907029478458 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_36' created.
# 6.826666666666667 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_37' created.
# 7.151746031746032 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_38' created.
# 7.337505668934241 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_39' created.
# 7.500045351473923 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_40' created.
# 7.685804988662132 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_41' created.
# 7.848344671201814 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_42' created.
# 8.057324263038549 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_43' created.
# 8.196643990929704 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_44' created.
# 8.544943310657596 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_45' created.
# 8.70748299319728 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_46' created.
# 8.893242630385487 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_47' created.
# 9.05578231292517 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_48' created.
# 9.241541950113378 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_49' created.
# 9.404081632653062 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_50' created.
# 9.566621315192744 	(sec): './result/oasis_karaoke/trim/oasis_karaoke_p_51' created.
# All files are 0.18498866213151927 sec long.
#
#
# Start Trim 'only_drum_p.wav'
# ./result/only_drum/trim folder created.
# 32 event(s) has been detected.
# 0.06965986394557823 	(sec): './result/only_drum/trim/only_drum_p_1' created.
# 0.2786394557823129 	(sec): './result/only_drum/trim/only_drum_p_2' created.
# 0.5108390022675737 	(sec): './result/only_drum/trim/only_drum_p_3' created.
# 0.7430385487528345 	(sec): './result/only_drum/trim/only_drum_p_4' created.
# 0.9752380952380952 	(sec): './result/only_drum/trim/only_drum_p_5' created.
# 1.230657596371882 	(sec): './result/only_drum/trim/only_drum_p_6' created.
# 1.4628571428571429 	(sec): './result/only_drum/trim/only_drum_p_7' created.
# 1.7182766439909296 	(sec): './result/only_drum/trim/only_drum_p_8' created.
# 1.9504761904761905 	(sec): './result/only_drum/trim/only_drum_p_9' created.
# 2.2058956916099772 	(sec): './result/only_drum/trim/only_drum_p_10' created.
# 2.4380952380952383 	(sec): './result/only_drum/trim/only_drum_p_11' created.
# 2.670294784580499 	(sec): './result/only_drum/trim/only_drum_p_12' created.
# 2.9257142857142857 	(sec): './result/only_drum/trim/only_drum_p_13' created.
# 3.1579138321995464 	(sec): './result/only_drum/trim/only_drum_p_14' created.
# 3.3901133786848074 	(sec): './result/only_drum/trim/only_drum_p_15' created.
# 3.645532879818594 	(sec): './result/only_drum/trim/only_drum_p_16' created.
# 3.877732426303855 	(sec): './result/only_drum/trim/only_drum_p_17' created.
# 4.1099319727891155 	(sec): './result/only_drum/trim/only_drum_p_18' created.
# 4.365351473922902 	(sec): './result/only_drum/trim/only_drum_p_19' created.
# 4.597551020408163 	(sec): './result/only_drum/trim/only_drum_p_20' created.
# 4.85297052154195 	(sec): './result/only_drum/trim/only_drum_p_21' created.
# 5.061950113378685 	(sec): './result/only_drum/trim/only_drum_p_22' created.
# 5.317369614512471 	(sec): './result/only_drum/trim/only_drum_p_23' created.
# 5.572789115646258 	(sec): './result/only_drum/trim/only_drum_p_24' created.
# 5.804988662131519 	(sec): './result/only_drum/trim/only_drum_p_25' created.
# 6.03718820861678 	(sec): './result/only_drum/trim/only_drum_p_26' created.
# 6.2693877551020405 	(sec): './result/only_drum/trim/only_drum_p_27' created.
# 6.501587301587302 	(sec): './result/only_drum/trim/only_drum_p_28' created.
# 6.757006802721088 	(sec): './result/only_drum/trim/only_drum_p_29' created.
# 6.989206349206349 	(sec): './result/only_drum/trim/only_drum_p_30' created.
# 7.244625850340136 	(sec): './result/only_drum/trim/only_drum_p_31' created.
# 7.500045351473923 	(sec): './result/only_drum/trim/only_drum_p_32' created.
# All files are 0.18498866213151927 sec long.

# %% [markdown]
# ### 3. Make Trim data(.wav) into Mel-Spectrogram(.jpg)

# %%
# checking trim_path_list
print("Let's extract mel-spectograms from trim data")
print(trim_path_list)
# Out:
# Let's extract mel-spectograms from trim data
# ['./result/oasis/trim', './result/oasis_karaoke/trim', './result/only_drum/trim']

# %%
def Mel_data(trim_path_list):
        for trim_path in trim_path_list:
            # setting mel_path in a result directory
            mel_path = trim_path[:-4] + 'mel'
            
            # Generating trim directory in a result/audio directory 
            try:
                os.makedirs(mel_path)
                print(f"{mel_path} folder created.")
            except:
                print("You already have folders")
                
            for t in os.listdir(trim_path):
                sample, sr = librosa.load(trim_path + '/' + t)
                if len(sample) < 1700 :
                    continue
                # warnings.filterwarnings(action='ignore')

                # mel
                plt.figure(figsize=(6.898,4.719))
                f_sample=librosa.feature.melspectrogram(y = sample)
                librosa.display.specshow(librosa.power_to_db(f_sample), cmap='jet', y_axis='mel')
                plt.clim(-70,20)
                plt.axis('off')
                plt.savefig(fname= mel_path + '/' + t + '_mel.jpg', bbox_inches='tight', pad_inches=0)
                plt.close()
            print(f"Complete saving {mel_path}")
        
        print("\n######### Complete saving all mel_spectrograms #########", end="\n\n")

# %%
Mel_data(trim_path_list)
# Out:
# ./result/oasis/mel folder created.
# Complete saving ./result/oasis/mel
# ./result/oasis_karaoke/mel folder created.
# Complete saving ./result/oasis_karaoke/mel
# ./result/only_drum/mel folder created.
# Complete saving ./result/only_drum/mel
#
# ######### Complete saving all mel_spectrograms #########

# %%
# checking mel directories
mel_path_list = list()
for t in trim_path_list:
    mel_path_list.append(t[:-4] + 'mel')
print (mel_path_list)
# Out:
# ['./result/oasis/mel', './result/oasis_karaoke/mel', './result/only_drum/mel']

# %% [markdown]
# # Test
# ## EfficientNet-B0 & Trained model parameters

# %%
import torch, json
from torch.utils.data import DataLoader

# User define Modules
from drumdataset_load import DrumDataset_test
from models import EfficientNet

# %%
with open('./info.json', 'r') as f:
    info = json.load(f)
    
labels = info["labels"]

# %%
for mel_path in mel_path_list:
    test_dataset = DrumDataset_test(labels, mel_path)
    test_loader = DataLoader(test_dataset, batch_size = 1, shuffle = False, num_workers = 0)
    del test_dataset

    save_path = mel_path[:-3]
    para_path="./parameters/parameter/efficientnet_b0_result_mel_aug.pth"
    net = EfficientNet.from_name('efficientnet-b0',in_channels=3, num_classes = 23)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    net.load_state_dict(torch.load(para_path))
    net.eval()
    net.to(device)
    
    print(f"\n########## {save_path[:-1]} ##########")
    
    f = open(save_path + 'onset_time.txt', 'r')
    onset_time = f.readlines()
    f. close()
    onset_time = list(map(lambda s: s.strip(), onset_time))

    with torch.no_grad():
        f = open(save_path + 'drum_tab.txt', 'w')
        i = 0
        for input_test,_ in test_loader:
            input_test = input_test.cuda()
            input_test = input_test.to("cuda").float()

            pred_test = net(input_test)
            # print(pred_test)
            __, predicted = torch.max(pred_test, 1)
            print(onset_time[i], 'sec\t: ', labels[predicted.item()])
            print(onset_time[i], 'sec\t: ', labels[predicted.item()], file=f)
            i+=1
    f.close()
# Out:
# ########## ./result/oasis ##########
# 0.06965986394557823 sec	:  R
# 0.16253968253968254 sec	:  rest
# 0.2089795918367347 sec	:  R
# 0.4179591836734694 sec	:  R
# 0.5108390022675737 sec	:  OH
# 0.7198185941043084 sec	:  R
# 0.8591383219954648 sec	:  S
# 1.207437641723356 sec	:  S
# 1.3931972789115645 sec	:  S+C
# 1.555736961451247 sec	:  B+CH
# 1.7647165532879818 sec	:  CH
# 1.9272562358276644 sec	:  CH
# 2.066575963718821 sec	:  CH
# 2.2523356009070294 sec	:  S+CH
# 2.5309750566893423 sec	:  rest
# 2.7631746031746034 sec	:  S+FT
# 2.948934240362812 sec	:  R
# 3.111473922902494 sec	:  CH
# 3.297233560090703 sec	:  B+C
# 3.436553287981859 sec	:  rest
# 3.6687528344671203 sec	:  S+FT
# 3.9706122448979593 sec	:  CH
# 4.156371882086168 sec	:  CH
# 4.31891156462585 sec	:  CH
# 4.504671201814059 sec	:  CH
# 4.6439909297052155 sec	:  B+R
# 4.85297052154195 sec	:  CH
# 5.015510204081632 sec	:  CH
# 5.363809523809524 sec	:  CH
# 5.456689342403628 sec	:  S+FT
# 5.526349206349207 sec	:  S+B
# 5.688888888888889 sec	:  B+R
# 5.851428571428571 sec	:  S+B
# 5.897868480725624 sec	:  CH
# 6.03718820861678 sec	:  B+CH
# 6.199727891156463 sec	:  OH
# 6.3854875283446715 sec	:  S+B+CH
# 6.733786848072563 sec	:  CH
# 6.896326530612245 sec	:  CH
# 7.082086167800454 sec	:  B
# 7.267845804988662 sec	:  CH
# 7.4071655328798185 sec	:  B+R
# 7.546485260770975 sec	:  R
# 7.732244897959184 sec	:  S+CH
# 7.778684807256236 sec	:  S+CH
# 8.034104308390022 sec	:  CH
# 8.243083900226758 sec	:  S+CH
# 8.289523809523809 sec	:  S+CH
# 8.475283446712018 sec	:  CH
# 8.614603174603175 sec	:  B+C
# 8.800362811791382 sec	:  B+CH
# 8.962902494331066 sec	:  CH
# 9.148662131519274 sec	:  S+CH
#
# ########## ./result/oasis_karaoke ##########
# 0.06965986394557823 sec	:  B+CH
# 0.25541950113378686 sec	:  R
# 0.44117913832199546 sec	:  S+B+CH
# 0.626938775510204 sec	:  B+CH
# 0.7894784580498866 sec	:  S+CH
# 0.9752380952380952 sec	:  B+CH
# 1.1377777777777778 sec	:  CH
# 1.3003174603174603 sec	:  S+CH
# 1.486077097505669 sec	:  CH
# 1.6486167800453515 sec	:  B+CH
# 1.811156462585034 sec	:  R
# 2.020136054421769 sec	:  B+CH
# 2.159455782312925 sec	:  CH
# 2.345215419501134 sec	:  B+CH
# 2.5309750566893423 sec	:  CH
# 2.670294784580499 sec	:  S+FT
# 3.0418140589569163 sec	:  rest
# 3.2043537414965986 sec	:  B+CH
# 3.3901133786848074 sec	:  B+CH
# 3.5526530612244898 sec	:  CH
# 3.7151927437641725 sec	:  B+CH
# 3.900952380952381 sec	:  CH
# 4.063492063492063 sec	:  B+FT
# 4.4117913832199545 sec	:  CH
# 4.574331065759637 sec	:  B+CH
# 4.73687074829932 sec	:  B+CH
# 4.922630385487528 sec	:  S+CH
# 5.085170068027211 sec	:  B+CH
# 5.270929705215419 sec	:  CH
# 5.433469387755102 sec	:  S+FT
# 5.7817687074829935 sec	:  B+CH
# 5.944308390022676 sec	:  B
# 6.130068027210885 sec	:  B+CH
# 6.292607709750567 sec	:  S+B+CH
# 6.478367346938776 sec	:  B+CH
# 6.640907029478458 sec	:  B+CH
# 6.826666666666667 sec	:  S+B+CH
# 7.151746031746032 sec	:  CH
# 7.337505668934241 sec	:  CH
# 7.500045351473923 sec	:  B+CH
# 7.685804988662132 sec	:  CH
# 7.848344671201814 sec	:  B+CH
# 8.057324263038549 sec	:  CH
# 8.196643990929704 sec	:  S+B+CH
# 8.544943310657596 sec	:  CH
# 8.70748299319728 sec	:  B
# 8.893242630385487 sec	:  B+CH
# 9.05578231292517 sec	:  FT
# 9.241541950113378 sec	:  B+CH
# 9.404081632653062 sec	:  CH
# 9.566621315192744 sec	:  B+FT
#
# ########## ./result/only_drum ##########
# 0.06965986394557823 sec	:  B+CH
# 0.2786394557823129 sec	:  CH
# 0.5108390022675737 sec	:  S
# 0.7430385487528345 sec	:  B+CH
# 0.9752380952380952 sec	:  CH
# 1.230657596371882 sec	:  CH
# 1.4628571428571429 sec	:  S
# 1.7182766439909296 sec	:  CH
# 1.9504761904761905 sec	:  B+CH
# 2.2058956916099772 sec	:  CH
# 2.4380952380952383 sec	:  S+CH
# 2.670294784580499 sec	:  B
# 2.9257142857142857 sec	:  CH
# 3.1579138321995464 sec	:  CH
# 3.3901133786848074 sec	:  S
# 3.645532879818594 sec	:  CH
# 3.877732426303855 sec	:  B+CH
# 4.1099319727891155 sec	:  CH
# 4.365351473922902 sec	:  S+CH
# 4.597551020408163 sec	:  B+CH
# 4.85297052154195 sec	:  CH
# 5.061950113378685 sec	:  CH
# 5.317369614512471 sec	:  S+CH
# 5.572789115646258 sec	:  CH
# 5.804988662131519 sec	:  B+CH
# 6.03718820861678 sec	:  CH
# 6.2693877551020405 sec	:  S+CH
# 6.501587301587302 sec	:  B+CH
# 6.757006802721088 sec	:  CH
# 6.989206349206349 sec	:  CH
# 7.244625850340136 sec	:  S+CH
# 7.500045351473923 sec	:  CH
